# %%
from bs4 import BeautifulSoup
import requests

url='https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/'

# %%
# Make a GET request to fetch the raw HTML content
html_content = requests.get(url).text

# Parse the html content
soup = BeautifulSoup(html_content, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard
#   </title>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-128.png" rel="icon" sizes="128x128" type="image/png"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-195.png" rel="icon" sizes="195x195" type="image/png"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-196.png" rel="icon" sizes="196x196" type="image/png"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-228.png" rel="icon" sizes="228x228" type="image/png"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-57.png" rel="apple-touch-icon-precomposed"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://cdn.motor1.com/images/static/insideevs/favicon-180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <meta content="https://cdn.motor1.com/images/static/insideevs/smalltile.png" name="msapplication-square128x128logo"/>
#   <meta content="https://cdn.motor1.com/images/static/insideevs/mediumtile.png" name="msapplication-square270x270logo"/>
#   <meta content="https://cdn.motor1.com/images/static/insideevs/largetile.png" name="msapplication-square580x580logo"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700" rel="stylesheet"/>
#   <script>
#    window.polymerLocale = 'en-US';
#         window.polymerLocalePath = 'https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/polymer2/locales1600957315/en-US.json';
#         var jsVars = {"services":{"brealtime":{"load":0,"id":"12851701"}},"ads":{"dfp":{"id":"6122441"}},"ui":{"auto_infinite_scroll":true}};
#   </script>
#   <link href="/rss/news/all/" rel="alternate" title="Latest news" type="application/rss+xml"/>
#   <link href="/rss/videos/all/" rel="alternate" title="Latest videos" type="application/rss+xml"/>
#   <meta content="The most comprehensive listing of plug-in EV sales for the United States. Compiled quarterly, yearly, and all-time by automaker." name="description"/>
#   <meta content="FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard" property="og:title"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" property="og:url"/>
#   <meta content="https://cdn.motor1.com/images/mgl/2oZrg/s1/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg" property="og:image"/>
#   <meta content="https://cdn.motor1.com/images/mgl/2oZrg/s1/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg" property="og:image:url"/>
#   <meta content="https://cdn.motor1.com/images/mgl/2oZrg/s1/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg" property="og:image:secure_url"/>
#   <meta content="image/jpeg" property="og:image:type"/>
#   <meta content="1920" property="og:image:width"/>
#   <meta content="1080" property="og:image:height"/>
#   <meta content="FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard: Sales" property="og:image:alt"/>
#   <meta content="The most comprehensive listing of plug-in EV sales for the United States. Compiled quarterly, yearly, and all-time by automaker." property="og:description"/>
#   <meta content="InsideEVs" property="og:site_name"/>
#   <meta content="100001157785488" property="fb:admins"/>
#   <meta content="984245018262500" property="fb:app_id"/>
#   <meta content="357684877628739" property="fb:pages"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="InsideEVs" property="twitter:site"/>
#   <meta content="FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard" property="twitter:title"/>
#   <meta content="The most comprehensive listing of plug-in EV sales for the United States. Compiled quarterly, yearly, and all-time by automaker." property="twitter:description"/>
#   <meta content="https://cdn.motor1.com/images/mgl/2oZrg/s3/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg" property="twitter:image"/>
#   <meta content="max-snippet:500, max-image-preview:large" property="robots"/>
#   <meta content="How are electric vehicle sales in the United States? We plug in all the available information in an attempt to help answer that question." name="speakable-description"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" hreflang="en" rel="alternate"/>
#   <link href="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" hreflang="x-default" rel="alternate"/>
#   <link href="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" rel="canonical"/>
#   <link href="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/amp/" rel="amphtml"/>
#   <link href="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/dist/css/0_ce0bed2888fc84c7f11d.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/dist/css/1_ce0bed2888fc84c7f11d.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/dist/css/3_ce0bed2888fc84c7f11d.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/dist/css/4_ce0bed2888fc84c7f11d.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/dist/css/13_ce0bed2888fc84c7f11d.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/dist/css/21_ce0bed2888fc84c7f11d.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/dist/css/index_articles_detail_ce0bed2888fc84c7f11d.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/ev-design/dist/css/0_6b2f8c0a7ae2eceb3640.css" rel="stylesheet" type="text/css"/>
#   <script>
#    window.isAuthorized = 0
#   </script>
#  </head>
#  <body class="nojs not-touch m1-fullwidth-layout bgWhite lightHeader hangingHeader" data-edtn="ev_us" data-spotim-id="" data-track-url="">
#   <div class="hiddenBlock">
#    <div class="apOutstream">
#     <div class="ap" data-dfp-attrs='{"msnt_env":"production","m1_banner_place":"outstream","m1_edition":"ev_us","m1_article_type":"news","m1_page_content_id":343998,"m1_page_type":"detail","m1_page_content_type":"article","m1_makes":["bmw","cadillac","audi","chevrolet","chrysler","fiat","ford","honda","hyundai","jaguar","kia","mercedes-benz","mini","mitsubishi","nissan","porsche","smart","subaru","toyota","volkswagen","volvo","general-motors","tesla","daimler"],"m1_categories":["sales"],"m1_banner_position":"outstream"}' data-dfp-code="EV/ev_us/Outstream" data-height="1" data-place="8" data-width="1" style="width:1px;min-height:1px;">
#     </div>
#    </div>
#   </div>
#   <div class="apOverlay m1-ap-overlay">
#    <div class="ap" data-dfp-attrs='{"msnt_env":"production","m1_banner_place":"overlay","m1_edition":"ev_us","m1_article_type":"news","m1_page_content_id":343998,"m1_page_type":"detail","m1_page_content_type":"article","m1_makes":["bmw","cadillac","audi","chevrolet","chrysler","fiat","ford","honda","hyundai","jaguar","kia","mercedes-benz","mini","mitsubishi","nissan","porsche","smart","subaru","toyota","volkswagen","volvo","general-motors","tesla","daimler"],"m1_categories":["sales"],"m1_banner_position":"overlay"}' data-dfp-code="EV/ev_us/Overlay" data-height="0" data-place="17" data-width="0" style="width:0px;min-height:0px;">
#    </div>
#   </div>
#   <div class="apOverlay m1-ap-overlay-2">
#    <div class="ap" data-dfp-attrs='{"msnt_env":"production","m1_banner_place":"overlay2","m1_edition":"ev_us","m1_article_type":"news","m1_page_content_id":343998,"m1_page_type":"detail","m1_page_content_type":"article","m1_makes":["bmw","cadillac","audi","chevrolet","chrysler","fiat","ford","honda","hyundai","jaguar","kia","mercedes-benz","mini","mitsubishi","nissan","porsche","smart","subaru","toyota","volkswagen","volvo","general-motors","tesla","daimler"],"m1_categories":["sales"],"m1_banner_position":"overlay2"}' data-dfp-code="EV/ev_us/Overlay2" data-height="0" data-place="18" data-width="0" style="width:0px;min-height:0px;">
#    </div>
#   </div>
#   <div class="apOverlay m1-ap-overlay-3">
#    <div class="ap" data-dfp-attrs='{"msnt_env":"production","m1_banner_place":"overlay3","m1_edition":"ev_us","m1_article_type":"news","m1_page_content_id":343998,"m1_page_type":"detail","m1_page_content_type":"article","m1_makes":["bmw","cadillac","audi","chevrolet","chrysler","fiat","ford","honda","hyundai","jaguar","kia","mercedes-benz","mini","mitsubishi","nissan","porsche","smart","subaru","toyota","volkswagen","volvo","general-motors","tesla","daimler"],"m1_categories":["sales"],"m1_banner_position":"overlay3"}' data-dfp-code="EV/ev_us/Overlay3" data-height="0" data-place="20" data-width="0" style="width:0px;min-height:0px;">
#    </div>
#   </div>
#   <div class="apOverlay m1-ap-overlay-4">
#    <div class="ap" data-dfp-attrs='{"msnt_env":"production","m1_banner_place":"overlay4","m1_edition":"ev_us","m1_article_type":"news","m1_page_content_id":343998,"m1_page_type":"detail","m1_page_content_type":"article","m1_makes":["bmw","cadillac","audi","chevrolet","chrysler","fiat","ford","honda","hyundai","jaguar","kia","mercedes-benz","mini","mitsubishi","nissan","porsche","smart","subaru","toyota","volkswagen","volvo","general-motors","tesla","daimler"],"m1_categories":["sales"],"m1_banner_position":"overlay4"}' data-dfp-code="EV/ev_us/Overlay4" data-height="0" data-place="21" data-width="0" style="width:0px;min-height:0px;">
#    </div>
#   </div>
#   <div class="root" data-role="page" id="page_index_articles_detail">
#    <div id="layout_header_spacer">
#    </div>
#    <div class="m1-header-main">
#     <div class="m1-header-main-box">
#      <div class="m1-header-main-box-wrapper">
#       <div class="box-item-left">
#        <div class="m1-hamburger-button" data-button="" data-clear="2" data-close-delay="0.5" data-delay="0.01" data-hide-scroll="m1-left-side-box" data-id="toggleBox" data-multi="" data-value="mainMenu" onclick="">
#         <span>
#         </span>
#         <span>
#         </span>
#         <span>
#         </span>
#        </div>
#       </div>
#       <div class="wrapper-box-item-center">
#        <div class="box-item-center">
#         <a class="m1-header-logo" href="/" title="Home">
#          <img alt="logo" class="logo_placeholder" src="data:image/png;base64,..."/>
#         </a>
#        </div>
#       </div>
#       <div class="m1-header-main-box-wrapper-sub" style="position: relative;">
#        <div class="box-item-pre-left">
#         <ul class="m1-navigation-main print-hide">
#          <li class="grand top left mobile">
#           <a href="/news/">
#            News
#           </a>
#          </li>
#          <li class="grand top left">
#           <a href="/reviews/">
#            Reviews
#           </a>
#          </li>
#          <li class="grand left">
#           <a href="/features/">
#            Features
#           </a>
#          </li>
#          <li class="mobile">
#           <a href="/tesla/">
#            Tesla
#           </a>
#          </li>
#          <li class="top left">
#           <a href="/reviews/344001/compare-evs/">
#            Compare EVs
#           </a>
#          </li>
#          <li class="left">
#           <a href="/news/344002/charger-guide/">
#            Charger Guide
#           </a>
#          </li>
#          <li class="left">
#           <a href="/features/category/buying-advice/">
#            Buying Advice
#           </a>
#          </li>
#          <li class="left current">
#           <a href="/news/343998/monthly-plug-in-ev-sales-scorecard/">
#            EV Sales Scorecard
#           </a>
#          </li>
#          <li class="mobile current">
#           <a href="/news/343998/monthly-plug-in-ev-sales-scorecard/">
#            EV Sales
#           </a>
#          </li>
#          <li class="left">
#           <a href="/makes/">
#            Makes
#           </a>
#          </li>
#          <li class="left">
#           <a href="/body-styles/">
#            Body Style
#           </a>
#          </li>
#          <li class="left top _blank">
#           <a href="https://insideevsforum.com/community/index.php" target="_blank">
#            Forum
#           </a>
#          </li>
#          <li class="left _blank">
#           <a href="https://www.myev.com/cars-for-sale" target="_blank">
#            Buy
#           </a>
#          </li>
#          <li class="podcast ico left">
#           <a href="https://insideevs.com/features/category/podcast/">
#            Podcast
#           </a>
#          </li>
#          <li class="photos ico left">
#           <a href="/photos/">
#            Photos
#           </a>
#          </li>
#          <li class="videos ico left">
#           <a href="/videos/">
#            Videos
#           </a>
#          </li>
#          <li class="top plugin-sale current">
#           <a href="/news/343998/monthly-plug-in-ev-sales-scorecard/">
#            Ev Sales Scorecard
#           </a>
#          </li>
#         </ul>
#        </div>
#        <!-- <div class="wrapper-plugin-sale">
#                         <div class="top plugin-sale">
#                             <a href="https://insideevs.com/monthly-plug-in-sales-scorecard/">Ev Sales Scorecard</a>
#                         </div>
#                     </div> -->
#        <div class="m1-search-form-button-wrapper">
#         <button class="m1-search-form-button-animate icon-search" data-button="" data-clear="1" data-id="toggleBox" data-multi="" data-value="searchBox" onclick="" type="submit">
#         </button>
#         <div class="m1-search-panel">
#          <form action="/search/" class="m1-search-form" data-native="0" id="header_search_form" method="GET" novalidate="novalidate">
#           <input autocomplete="off" class="m1-search-panel-input m1-search-form-text" id="search_input" name="q" placeholder="Search" type="text" value=""/>
#           <button class="m1-search-panel-button m1-search-form-button-animate icon-search" type="submit">
#           </button>
#           <button class="m1-search-panel-button m1-drawer-close-button" data-button="" data-clear="1" data-id="toggleBox" data-multi="" data-toggle="1" data-value="searchBox" onclick="">
#           </button>
#          </form>
#         </div>
#        </div>
#       </div>
#       <div class="box-item-right">
#        <div class="m1-editions-switcher-m" data-button="" data-clear="2" data-close-delay="0.5" data-delay="0.01" data-hide-scroll="m1-scrollbar" data-id="toggleBox" data-multi="" data-value="editionsMenu" onclick="">
#         <span class="edf edf-230">
#         </span>
#        </div>
#        <div class="m1-editions-switcher" data-button="" data-clear="2" data-close-delay="0.5" data-delay="0.01" data-hide-scroll="m1-scrollbar" data-id="toggleBox" data-multi="" data-value="editionsMenu" onclick="">
#         <span class="edf edf-230">
#         </span>
#         <span class="title">
#          USA / Global
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="m1-header-ad top-banner-placeholder">
#     <div class="m1-gapb-topside">
#      <div class="m1-apb mleaderboard">
#       <div class="ap" data-dfp-attrs='{"msnt_env":"production","m1_banner_place":"top-banners","m1_edition":"ev_us","m1_article_type":"news","m1_page_content_id":343998,"m1_page_type":"detail","m1_page_content_type":"article","m1_makes":["bmw","cadillac","audi","chevrolet","chrysler","fiat","ford","honda","hyundai","jaguar","kia","mercedes-benz","mini","mitsubishi","nissan","porsche","smart","subaru","toyota","volkswagen","volvo","general-motors","tesla","daimler"],"m1_categories":["sales"],"m1_banner_position":"top","m1_banner_position_view":"above-the-fold"}' data-dfp-code="EV/ev_us/Mobile_Leaderboard" data-height="1" data-place="10" data-sizes="320x1,320x50,320x100" data-width="320" style="width:320px;min-height:1px;">
#       </div>
#      </div>
#      <div class="m1-apb leaderboard">
#       <div class="ap" data-dfp-attrs='{"msnt_env":"production","m1_banner_place":"top-banners","m1_edition":"ev_us","m1_article_type":"news","m1_page_content_id":343998,"m1_page_type":"detail","m1_page_content_type":"article","m1_makes":["bmw","cadillac","audi","chevrolet","chrysler","fiat","ford","honda","hyundai","jaguar","kia","mercedes-benz","mini","mitsubishi","nissan","porsche","smart","subaru","toyota","volkswagen","volvo","general-motors","tesla","daimler"],"m1_categories":["sales"],"m1_banner_position":"top","m1_banner_position_view":"above-the-fold"}' data-dfp-code="EV/ev_us/Leaderboard" data-height="1" data-place="1" data-sizes="728x1,1x1,728x90" data-width="728" style="width:728px;min-height:1px;">
#       </div>
#      </div>
#      <div class="m1-apb super">
#       <div class="ap" data-dfp-attrs='{"msnt_env":"production","m1_banner_place":"top-banners","m1_edition":"ev_us","m1_article_type":"news","m1_page_content_id":343998,"m1_page_type":"detail","m1_page_content_type":"article","m1_makes":["bmw","cadillac","audi","chevrolet","chrysler","fiat","ford","honda","hyundai","jaguar","kia","mercedes-benz","mini","mitsubishi","nissan","porsche","smart","subaru","toyota","volkswagen","volvo","general-motors","tesla","daimler"],"m1_categories":["sales"],"m1_banner_position":"top","m1_banner_position_view":"above-the-fold"}' data-dfp-code="EV/ev_us/Super" data-height="1" data-place="6" data-sizes="970x1,1x1,970x90,970x250,980x250" data-width="970" style="width:970px;min-height:1px;">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="pageAdSkin" id="page_skin_top">
#     <div class="adSizer">
#      <img alt="" src="..."/>
#     </div>
#     <a class="pageAdSkinUrl">
#     </a>
#    </div>
#    <script type="application/ld+json">
#     {"@context":"http:\/\/schema.org","@type":"NewsArticle","headline":"FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard","description":"The most comprehensive listing of plug-in EV sales for the United States. Compiled quarterly, yearly, and all-time by automaker.","author":{"@type":"Person","name":"Steven Loveday"},"url":"https:\/\/insideevs.com\/news\/343998\/monthly-plug-in-ev-sales-scorecard\/","datePublished":"2020-01-17T13:28:54Z","dateModified":"2020-05-07T14:57:15Z","publisher":{"@type":"Organization","name":"InsideEVs","logo":{"@type":"ImageObject","url":"https:\/\/insideevs.com\/logo.jpg","width":"325","height":"60"}},"image":{"@type":"ImageObject","url":"https:\/\/cdn.motor1.com\/images\/mgl\/2oZrg\/s1\/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg","width":"1920","height":"1080"},"mainEntityOfPage":{"@type":"WebPage","url":"https:\/\/insideevs.com\/news\/343998\/monthly-plug-in-ev-sales-scorecard\/"},"wordCount":"1056"}
#    </script>
#    <script type="application/ld+json">
#     {"@context":"https:\/\/schema.org\/","@type":"WebPage","name":"FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard","speakable":{"@type":"SpeakableSpecification","xpath":["\/html\/head\/title","\/html\/head\/meta[@name='speakable-description']\/@content"]},"url":"https:\/\/insideevs.com\/news\/343998\/monthly-plug-in-ev-sales-scorecard\/"}
#    </script>
#    <script type="application/ld+json">
#     {"@context":"https:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https:\/\/insideevs.com\/"},{"@type":"ListItem","position":2,"name":"News","item":"https:\/\/insideevs.com\/news\/"},{"@type":"ListItem","position":3,"name":"Sales","item":"https:\/\/insideevs.com\/news\/category\/sales\/"}]}
#    </script>
#    <div class="pre-center breadcrumbs-area">
#     <div class="breadcrumbs" slot="breadcrumbs">
#      <a href="/">
#       Home
#      </a>
#      <span class="sep">
#      </span>
#      <a href="/news/">
#       News
#      </a>
#      <span class="sep">
#      </span>
#      <a href="/news/category/sales/">
#       Sales
#      </a>
#     </div>
#     <h1 class="m1-article-title">
#      FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard
#     </h1>
#    </div>
#    <div class="pre-center">
#     <div class="articleHeader">
#      <div class="box-center">
#       <div class="originalImage">
#        <img alt="Deep Dive Into Tesla Model 3 Price Changes: What's Going On Here?" src="https://cdn.motor1.com/images/mgl/2oZrg/s4/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg"/>
#       </div>
#       <div class="articlePoster scrollTieBox" id="article_poster">
#        <style type="text/css">
#         @media only screen{#article_poster{background-image:url(https://cdn.motor1.com/images/mgl/2oZrg/s5/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg);}}
# @media only screen and (min-width : 445px){#article_poster{background-image:url(https://cdn.motor1.com/images/mgl/2oZrg/s4/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg);}}
# @media only screen and (min-width : 1024px){#article_poster{background-image:url(https://cdn.motor1.com/images/mgl/2oZrg/s3/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg);}}
# @media only screen and (min-width : 1280px){#article_poster{background-image:url(https://cdn.motor1.com/images/mgl/2oZrg/s2/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg);}}
# @media only screen and (min-width : 1440px){#article_poster{background-image:url(https://cdn.motor1.com/images/mgl/2oZrg/s1/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg);}}
#
#
# @media only screen and (-webkit-min-device-pixel-ratio : 2),
#        only screen and (min--moz-device-pixel-ratio : 2),
#        only screen and (min-device-pixel-ratio : 2){
#            #article_poster{
#                background-image:url(https://cdn.motor1.com/images/mgl/2oZrg/s1/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg);
#             }
#         }
#
# @media only screen and (min-width : 445px) and (-webkit-min-device-pixel-ratio : 2),
#        only screen and (min-width : 445px) and (min--moz-device-pixel-ratio : 2),
#        only screen and (min-width : 445px) and (min-device-pixel-ratio : 2){
#            #article_poster{
#                background-image:url(https://cdn.motor1.com/images/mgl/2oZrg/s3/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg);
#             }
#         }
#
# @media only screen and (min-width : 1024px) and (-webkit-min-device-pixel-ratio : 2),
#        only screen and (min-width : 1024px) and (min--moz-device-pixel-ratio : 2),
#        only screen and (min-width : 1024px) and (min-device-pixel-ratio : 2){
#            #article_poster{
#                background-image:url(https://cdn.motor1.com/images/mgl/2oZrg/s1/deep-dive-into-tesla-model-3-price-changes-what-s-going-on-here.jpg);
#             }
#         }
#        </style>
#        <img alt="" class="sizer" src="..."/>
#       </div>
#      </div>
#      <div class="articleTitle">
#       <div class="box-center">
#        <div class="pre-center">
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="pre-center padding b-padding-skin pre-center-feature" id="post_box">
#     <div data-bubbles="keyword" data-name="id" data-url="/news/store-keywords/">
#     </div>
#     <div class="content-area" id="article_box">
#      <span class="item" style="display: none;">
#       <a href="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" style="display: none">
#        FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard
#       </a>
#      </span>
#      <span class="type" style="display: none;">
#       product
#      </span>
#      <span class="dt-published" style="display: none;">
#       2020-01-17 13:28:54
#      </span>
#      <a class="u-url" href="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" rel="bookmark" style="display: none">
#       https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/
#      </a>
#      <span class="p-item item" style="display: none;">
#       <span class="fn">
#        BMW                                            Cadillac                                            Audi                                            Chevrolet                                            Chrysler                                            Fiat                                            Ford                                            Honda                                            Hyundai                                            Jaguar                                            Kia                                            Mercedes-Benz                                            Mini                                            Mitsubishi                                            Nissan                                            Porsche                                            Smart                                            Subaru                                            Toyota                                            Volkswagen                                            Volvo                                            General Motors                                            Tesla                                            Daimler
#       </span>
#      </span>
#      <span class="p-category" style="display: none;">
#       Sales
#      </span>
#      <div class="content-area-box">
#       <div class="postTopInfo">
#        <div class="postMeta-Top">
#         <div class="postDate">
#          <span class="date" data-time="1579249734">
#           <a href="/2020/01/17/">
#            Jan 17, 2020
#           </a>
#           <span class="small">
#            at
#           </span>
#           8:28am ET
#          </span>
#         </div>
#         <div class="shareTrendingBox">
#          <script async="" id="dsq-count-scr" src="//insideevscom.disqus.com/count.js">
#          </script>
#          <a class="disqus-comment-count" data-disqus-identifier="en-article-343998" data-disqus-url="/news/343998/monthly-plug-in-ev-sales-scorecard/" href="/news/343998/monthly-plug-in-ev-sales-scorecard/#comments" title="Add a comment">
#          </a>
#          <div class="big-shareBox shareBox share-box-dropdown to-down" slot="share-box">
#           <div class="share-box-wrapper">
#            <span class="shareBox-separator" data-button="" data-id="toggleBox" data-static="" data-value="share-list-1601752678" onclick="">
#             <span class="active">
#              <span class="icon-plus">
#               +
#              </span>
#             </span>
#             <span class="passive">
#              <span class="icon-plus">
#               +
#              </span>
#             </span>
#            </span>
#            <a class="share-button" href="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/">
#             <span class="icon share-empty">
#             </span>
#            </a>
#            <div class="share-list" data-button-target="share-list-1601752678">
#             <ul>
#              <li class="facebook">
#               <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="600" data-id="share" data-name="network_id" data-share-network="Facebook" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="1" data-width="600" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F" target="_blank">
#                <span class="social-bg icon facebook">
#                </span>
#                <span class="name">
#                 Share on Facebook
#                </span>
#               </a>
#              </li>
#              <li class="twitter">
#               <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="450" data-id="share" data-name="network_id" data-share-network="Twitter" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="2" data-width="600" href="https://twitter.com/intent/tweet?url=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F&amp;text=FINAL+UPDATE%3A+Quarterly+Plug-In+EV+Sales+Scorecard&amp;via=insideevs.com" target="_blank">
#                <span class="social-bg icon twitter">
#                </span>
#                <span class="name">
#                 Share on Twitter
#                </span>
#               </a>
#              </li>
#              <li class="linkedin">
#               <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="600" data-id="share" data-name="network_id" data-share-network="LinkedIn" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="3" data-width="600" href="https://www.linkedin.com/cws/share?url=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F" target="_blank">
#                <span class="social-bg icon linkedin">
#                </span>
#                <span class="name">
#                 Share on LinkedIn
#                </span>
#               </a>
#              </li>
#              <li class="flipboard">
#               <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="600" data-id="share" data-name="network_id" data-share-network="Flipboard" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="7" data-width="600" href="https://share.flipboard.com/bookmarklet/popout?url=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F&amp;title=FINAL+UPDATE%3A+Quarterly+Plug-In+EV+Sales+Scorecard&amp;v=2" target="_blank">
#                <span class="social-bg icon flipboard">
#                </span>
#                <span class="name">
#                 Share on Flipboard
#                </span>
#               </a>
#              </li>
#              <li class="reddit">
#               <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="600" data-id="share" data-name="network_id" data-share-network="Reddit" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="6" data-width="900" href="https://www.reddit.com/submit?url=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F" target="_blank">
#                <span class="social-bg icon reddit">
#                </span>
#                <span class="name">
#                 Share on Reddit
#                </span>
#               </a>
#              </li>
#              <li class="whatsapp">
#               <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="600" data-id="share" data-name="network_id" data-share-network="WhatsApp" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="6" data-width="600" href="https://api.whatsapp.com/send?text=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F" target="_blank">
#                <span class="social-bg icon whatsapp">
#                </span>
#                <span class="name">
#                 Share on WhatsApp
#                </span>
#               </a>
#              </li>
#              <li class="mailto">
#               <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="400" data-id="mailTo" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-width="600" href="mailto:?body=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F&amp;subject=FINAL%20UPDATE%3A%20Quarterly%20Plug-In%20EV%20Sales%20Scorecard" target="_blank">
#                <span class="social-bg icon mailto">
#                </span>
#                <span class="name">
#                 Send to email
#                </span>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="postAuthorBox withAvatar" xmlns="http://www.w3.org/1999/xhtml">
#         <div class="postAuthorThumb">
#          <a class="userRThumb" href="/info/team/steven-loveday/">
#           <img alt="Steven Loveday" src="https://cdn.motor1.com/images/atr/z37/s4/steven-loveday.jpg"/>
#          </a>
#         </div>
#         <div class="postAuthorInfo">
#          <div class="postAuthor">
#           <span class="name">
#            <span class="label">
#             By
#            </span>
#            :
#            <a class="author" content="Steven Loveday" href="/info/team/steven-loveday/">
#             Steven Loveday
#            </a>
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="clear">
#        </div>
#       </div>
#       <div class="postContent content-wrapper">
#        <div class="postBody description e-content">
#         <p>
#          As stated below, "we won't be updating this chart after 2019, but we'll still publish articles each month showcasing data gleaned from automakers that do choose to report. So, we'll have a number of articles about deliveries of each 'chart-topping' EV." If the situation changes in the future, we'll let you know. Thank you as always for the support.
#         </p>
#         <div class="apInarticleSmallRes">
#          <div class="ap" data-dfp-attrs='{"lazy":1,"msnt_env":"production","m1_banner_place":"rectangle_first","m1_edition":"ev_us","m1_article_type":"news","m1_page_content_id":343998,"m1_page_type":"detail","m1_page_content_type":"article","m1_makes":["bmw","cadillac","audi","chevrolet","chrysler","fiat","ford","honda","hyundai","jaguar","kia","mercedes-benz","mini","mitsubishi","nissan","porsche","smart","subaru","toyota","volkswagen","volvo","general-motors","tesla","daimler"],"m1_categories":["sales"],"m1_banner_position":"first-inarticle-small-res"}' data-dfp-code="EV/ev_us/Rectangle" data-height="1" data-place="25" data-sizes="300x1,300x250" data-width="300" style="width:300px;min-height:1px;">
#          </div>
#         </div>
#         <hr/>
#         <p>
#          We'll be reporting
#          <strong>
#           2019 Q4 EV Sales
#          </strong>
#          beginning Friday, January 3, and continuing throughout the following week. However, it's important to note that there will still be some missing data since many automakers refuse to report EV sales. Nonetheless, stay tuned in the coming days as we'll be beginning to add automaker reported numbers to the chart for the last few months.
#         </p>
#         <blockquote>
#          <p>
#           <em>
#            <strong>
#             FINAL UPDATE (January 17, 2020 @ 8:30 AM ET):
#            </strong>
#            Q4 numbers and all totals are now in.
#           </em>
#          </p>
#          <p>
#           <em>
#            <strong>
#             Information about our final update (January 16, 2020 @ 9:12 AM ET):
#            </strong>
#            As you can see, we've added all estimated data to complete the sales chart. At the bottom of the chart, you'll find a color-coded key.
#           </em>
#          </p>
#          <p>
#           <em>
#            <strong>
#             EDITOR'S NOTE (January 6, 2020 @ 9:20 PM ET):
#            </strong>
#            At this point, all numbers that are officially reported by automakers are already in the chart. Over the course of the next week or so, we will be putting together final Q4 estimates for the remaining models to get a rough idea of how the year played out as a whole. The numbers will be based on current inventory, sales data and inventory from the previous three quarters, sales data from Q4 2018, and any registration data we can gather. Stay tuned as we plan to have final data collected no later than January 15, 2020.
#           </em>
#          </p>
#          <p>
#           <em>
#            <strong>
#             UPDATE (January 3, 2020 @ 10:25 AM):
#            </strong>
#            We've entered preliminary quarterly numbers into the chart for
#            <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22tesla%22%7D" data-type-id="1" href="https://insideevs.com/tesla/" rel="noopener" target="_blank">
#             Tesla
#            </a>
#            . Keep in mind that we'll have more December data later this month, which could result in some adjustments to our estimates.
#           </em>
#          </p>
#         </blockquote>
#         <section class="relatedContent-new" contenteditable="false" data-params="%7B%22type_id%22%3A0%2C%22title_id%22%3A%22%22%2C%22items%22%3A%5B%7B%22article_edition_id%22%3A%22390762%22%2C%22title%22%3A%22Tesla%20Delivers%20Record%20112%2C000%20Model%203%2C%20S%20%26%20X%20Globally%20In%20Q4%202019%22%2C%22alias%22%3A%22tesla-q4-sales-production-deliveries%22%2C%22section%22%3A%221%22%2C%22is_checked%22%3Atrue%2C%22is_video%22%3A%220%22%2C%22images%22%3A%7B%22s5%22%3A%22https%3A%2F%2Fcdn.motor1.com%2Fimages%2Fmgl%2FP1g78%2Fs5%2Ftesla-model-3-performance-vs-zero-motorcycles-sr-f.jpg%22%7D%7D%2C%7B%22article_edition_id%22%3A%22389990%22%2C%22title%22%3A%22Global%20EV%20Sales%20In%20November%202019%3A%20Down%2026%25%20Year-Over-Year%22%2C%22alias%22%3A%22global-ev-sales-in-november-2019%22%2C%22section%22%3A%221%22%2C%22is_checked%22%3Atrue%2C%22is_video%22%3A%220%22%2C%22images%22%3A%7B%22s5%22%3A%22https%3A%2F%2Fcdn.motor1.com%2Fimages%2Fmgl%2FOYA2A%2Fs5%2Ftesla-model-3.jpg%22%7D%7D%5D%7D" data-widget="related-content" data-widget-size="content" draggable="true">
#          <h2 class="trending-content_header">
#           More Sales-Related Content:
#          </h2>
#          <div class="wrapper-related-item">
#           <div class="related-item">
#            <a href="https://insideevs.com/news/390762/tesla-q4-sales-production-deliveries/" rel="noopener" target="_blank">
#             <span class="lazy related-item-img">
#              <img alt="tesla q4 sales production deliveries" data-src="https://cdn.motor1.com/images/mgl/P1g78/s6/tesla-model-3-performance-vs-zero-motorcycles-sr-f.jpg" data-srcset="https://cdn.motor1.com/images/mgl/P1g78/s6/tesla-model-3-performance-vs-zero-motorcycles-sr-f.jpg 1x,
# https://cdn.motor1.com/images/mgl/P1g78/s4/tesla-model-3-performance-vs-zero-motorcycles-sr-f.jpg 2x" src="https://cdn.motor1.com/custom/share/placeholder_0.jpg"/>
#             </span>
#             <span class="title-related-item">
#              Tesla Delivers Record 112,000 Model 3, S &amp; X Globally In Q4 2019
#             </span>
#            </a>
#           </div>
#           <div class="related-item">
#            <a href="https://insideevs.com/news/389990/global-ev-sales-in-november-2019/" rel="noopener" target="_blank">
#             <span class="lazy related-item-img">
#              <img alt="global ev sales in november 2019" data-src="https://cdn.motor1.com/images/mgl/OYA2A/s6/tesla-model-3.jpg" data-srcset="https://cdn.motor1.com/images/mgl/OYA2A/s6/tesla-model-3.jpg 1x,
# https://cdn.motor1.com/images/mgl/OYA2A/s4/tesla-model-3.jpg 2x" src="https://cdn.motor1.com/custom/share/placeholder_1.jpg"/>
#             </span>
#             <span class="title-related-item">
#              Global EV Sales In November 2019: Down 26% Year-Over-Year
#             </span>
#            </a>
#           </div>
#          </div>
#         </section>
#         <blockquote>
#          <p>
#           <em>
#            <strong>
#             Important considerations going forward:
#            </strong>
#            It appears we won't have a reliable method for reporting sales figures for many models. While many are not models that make a huge impact on our monthly sales chart, but may in the future (i.e.
#            <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22hyundai%22%7D" data-type-id="1" href="https://insideevs.com/hyundai/" rel="noopener" target="_blank">
#             Hyundai
#            </a>
#            ,
#            <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22kia%22%7D" data-type-id="1" href="https://insideevs.com/kia/" rel="noopener" target="_blank">
#             Kia
#            </a>
#            ,
#            <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22porsche%22%7D" data-type-id="1" href="https://insideevs.com/porsche/" rel="noopener" target="_blank">
#             Porsche
#            </a>
#            ,
#            <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22subaru%22%7D" data-type-id="1" href="https://insideevs.com/subaru/" rel="noopener" target="_blank">
#             Subaru
#            </a>
#            ,
#            <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22volvo%22%7D" data-type-id="1" href="https://insideevs.com/volvo/" rel="noopener" target="_blank">
#             Volvo
#            </a>
#            ), some do, like
#            <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22general-motors%22%7D" data-type-id="1" href="https://insideevs.com/general-motors/" rel="noopener" target="_blank">
#             GM
#            </a>
#            and
#            <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22ford%22%7D" data-type-id="1" href="https://insideevs.com/ford/" rel="noopener" target="_blank">
#             Ford
#            </a>
#            . We're also learning that other sites are now estimating numbers from these automakers without exposing that and/or not sharing them at all.
#           </em>
#          </p>
#          <p>
#           <em>
#            With that said,
#            <strong>
#             we won't be updating this chart after 2019
#            </strong>
#            , but we'll still publish articles each month showcasing data gleaned from automakers that do choose to report. So, we'll have a number of articles about deliveries of each "chart-topping" EV.
#           </em>
#          </p>
#          <p>
#           <em>
#            While we really hate to move forward this way, we have no choice at this point. Sadly, our chart has become almost purely based on estimated date (which was once supported by actual data).
#           </em>
#          </p>
#          <p>
#           <em>
#            As always, thank you for the continued support!
#           </em>
#          </p>
#         </blockquote>
#         <hr/>
#         <p>
#          Note that
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22bmw%22%7D" data-type-id="1" href="https://insideevs.com/bmw/" rel="noopener" target="_blank">
#           BMW
#          </a>
#          has decided for some time to no longer give model breakdowns or a final EV number, but rather a percentage decrease YoY, which has been huge in the last few months. But now, the automaker isn't even sharing its EV sales numbers/percentage at all. Still,
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22make_alias%22%3A%22bmw%22%2C%22alias%22%3A%22i3%22%7D" data-type-id="0" href="https://insideevs.com/bmw/i3/" rel="noopener" target="_blank">
#           i3
#          </a>
#          and
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22make_alias%22%3A%22bmw%22%2C%22alias%22%3A%22i8%22%7D" data-type-id="0" href="https://insideevs.com/bmw/i8/" rel="noopener" target="_blank">
#           i8
#          </a>
#          numbers will be official as reported by BMW.
#         </p>
#         <p>
#          While
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22mercedes-benz%22%7D" data-type-id="1" href="https://insideevs.com/mercedes-benz/" rel="noopener" target="_blank">
#           Mercedes
#          </a>
#          is willing to provide
#          <em>
#           IEV
#          </em>
#          with a "total" number of plug-in vehicles sold for the month, the totals for each model are unverified by the automaker.
#         </p>
#         <p>
#          Many other automakers like Hyundai, Kia, Subaru, Volvo, Porsche, and Jaguar don't reveal any EV sales figures.
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22tesla%22%7D" data-type-id="1" href="https://insideevs.com/tesla/" rel="noopener" target="_blank">
#           Tesla
#          </a>
#          reports its overall global deliveries every quarter, but that doesn't help with U.S. sales.
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22general-motors%22%7D" data-type-id="1" href="https://insideevs.com/general-motors/" rel="noopener" target="_blank">
#           GM
#          </a>
#          (
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22chevrolet%22%7D" data-type-id="1" href="https://insideevs.com/chevrolet/" rel="noopener" target="_blank">
#           Chevrolet
#          </a>
#          and
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22cadillac%22%7D" data-type-id="1" href="https://insideevs.com/cadillac/" rel="noopener" target="_blank">
#           Cadillac
#          </a>
#          ) and
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22ford%22%7D" data-type-id="1" href="https://insideevs.com/ford/" rel="noopener" target="_blank">
#           Ford
#          </a>
#          , among others, have chosen to just report on a quarterly basis, but again, there's often no breakdown of EV models delivered.
#         </p>
#         <div class="item m1-ap-native">
#          <div class="ap" data-dfp-attrs='{"m1_native":"2","msnt_env":"production","m1_banner_place":"native","m1_edition":"ev_us","m1_article_type":"news","m1_page_content_id":343998,"m1_page_type":"detail","m1_page_content_type":"article","m1_makes":["bmw","cadillac","audi","chevrolet","chrysler","fiat","ford","honda","hyundai","jaguar","kia","mercedes-benz","mini","mitsubishi","nissan","porsche","smart","subaru","toyota","volkswagen","volvo","general-motors","tesla","daimler"],"m1_categories":["sales"],"m1_banner_position":"native"}' data-dfp-code="EV/ev_us/Native" data-height="1" data-place="22" data-sizes="fluid,1x1" data-width="1">
#          </div>
#         </div>
#         <p>
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22alias%22%3A%22toyota%22%7D" data-type-id="1" href="https://insideevs.com/toyota/" rel="noopener" target="_blank">
#           Toyota
#          </a>
#          stopped reporting
#          <a data-inline-widget="internal-links" data-params="%7B%22is_checked%22%3Atrue%2C%22make_alias%22%3A%22toyota%22%2C%22alias%22%3A%22prius-prime%22%7D" data-type-id="0" href="https://insideevs.com/toyota/prius-prime/" rel="noopener" target="_blank">
#           Prius Prime
#          </a>
#          sales and has instead made the decision to just post overall Prius sales.
# ...
#          </a>
#         </li>
#         <li class="flipboard">
#          <a class="icon-flipboard-redirect-link" href="https://flipboard.com/@InsideEVs" target="_blank">
#          </a>
#         </li>
#         <li class="gnews">
#          <a class="icon-gnews-redirect-link" href="https://news.google.com/publications/CAAqBwgKMLHIlAswkJCqAw" target="_blank">
#          </a>
#         </li>
#         <li class="youtube">
#          <a class="icon-youtube-redirect-link" href="https://www.youtube.com/channel/UCw4aq8JMlCMBMOQ0PliCkIQ?sub_confirmation=1" target="_blank">
#          </a>
#         </li>
#         <li class="rss">
#          <a class="icon-rss-redirect-link" href="/rss/">
#          </a>
#         </li>
#        </ul>
#        <ul class="m1-info-menu">
#         <li>
#          <a href="/info/about-us/">
#           About Us
#          </a>
#         </li>
#         <li>
#          <a href="https://newsletter.insideevs.com/signup/" target="_blank">
#           Newsletter
#          </a>
#         </li>
#         <li>
#          <a href="/info/contact/">
#           Contact
#          </a>
#         </li>
#         <li>
#          <a href="/info/feedback/tip-us/">
#           Tip us
#          </a>
#         </li>
#         <li>
#          <a href="https://accounts.motorsportnetwork.com/legal/privacy-policy" target="_blank">
#           Privacy policy
#          </a>
#         </li>
#         <li>
#          <!-- OneTrust Cookies Settings button start -->
#          <button class="ot-sdk-show-settings" id="ot-sdk-btn">
#           Cookie Settings
#          </button>
#          <!-- OneTrust Cookies Settings button end -->
#         </li>
#         <li>
#          <a href="/info/cookie-policy/">
#           Cookie policy
#          </a>
#         </li>
#         <li>
#          <a href="/info/advertising/">
#           Advertising
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="m1-msn-menus-box">
#        <ul class="m1-msn-menu">
#         <li class="autoclassics">
#          <a href="https://www.autoclassics.com/" target="_blank">
#           www.autoclassics.com
#          </a>
#         </li>
#         <li class="motor1">
#          <a href="https://www.motor1.com/" target="_blank">
#           www.motor1.com
#          </a>
#         </li>
#         <li class="myen">
#          <a href="https://www.myev.com/" target="_blank">
#           www.myev.com/
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="m1-footer">
#        © 2020
#        <a class="m1-msn-name" href="https://www.motorsportnetwork.com/company/about" target="_blank">
#         Motorsport Network.
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="m1-drawer-overlay">
#    </div>
#   </div>
#   <div class="m1-right-side">
#    <div class="m1-drawer right-to-left disabled" data-button-target="editionsMenu">
#     <div class="m1-drawer-close-button active" data-button="" data-clear="2" data-close-delay="0.5" data-hide-scroll="m1-scrollbar" data-id="toggleBox" data-multi="" data-toggle="1" data-value="editionsMenu" onclick="">
#     </div>
#     <div class="m1-editions-switcher active" data-button="" data-clear="2" data-close-delay="0.5" data-delay="0.01" data-id="toggleBox" data-multi="" data-toggle="1" data-value="editionsMenu" onclick="">
#      <span class="edf edf-230">
#      </span>
#      <span class="title">
#       USA / Global
#      </span>
#     </div>
#     <div class="m1-editions-label">
#      Our International Editions
#     </div>
#     <div class="m1-editions-box m1-scrollbar">
#      <ul class="m1-editions-list">
#       <li class="current">
#        <a href="https://insideevs.com">
#         <span class="flags">
#          <span class="edf edf-230">
#          </span>
#         </span>
#         <span class="label">
#          InsideEVs: USA / Global
#         </span>
#        </a>
#       </li>
#       <li>
#        <a href="https://insideevs.fr">
#         <span class="flags">
#          <span class="edf edf-72">
#          </span>
#          <span class="edf edf-21">
#          </span>
#          <span class="edf edf-211">
#          </span>
#          <span class="edf edf-145">
#          </span>
#          <span class="edf edf-128">
#          </span>
#         </span>
#         <span class="label">
#          InsideEVs: France
#         </span>
#        </a>
#       </li>
#       <li>
#        <a href="https://insideevs.it">
#         <span class="flags">
#          <span class="edf edf-106">
#          </span>
#         </span>
#         <span class="label">
#          InsideEVs: Italy
#         </span>
#        </a>
#       </li>
#       <li>
#        <a href="https://insideevs.uol.com.br">
#         <span class="flags">
#          <span class="edf edf-30">
#          </span>
#          <span class="edf edf-177">
#          </span>
#         </span>
#         <span class="label">
#          InsideEVs: Brasil
#         </span>
#        </a>
#       </li>
#       <li>
#        <a href="https://insideevs.ru">
#         <span class="flags">
#          <span class="edf edf-182">
#          </span>
#          <span class="edf edf-20">
#          </span>
#          <span class="edf edf-227">
#          </span>
#          <span class="edf edf-112">
#          </span>
#         </span>
#         <span class="label">
#          InsideEVs: Russia
#         </span>
#        </a>
#       </li>
#       <li>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="m1-drawer-overlay">
#    </div>
#   </div>
#   <m1-check-availability-response-dialog edition="ev_us" oem-url="/buy/new/lead/" user-data='{"email":"","zip":"20149","phone":"","firstName":"","lastName":""}' vin-url="/buy/used/lead/">
#   </m1-check-availability-response-dialog>
#   <div id="share_box_content_wrapper">
#    <div class="big-shareBox shareBox share-box-dropdown to-down" slot="share-box">
#     <div class="share-box-wrapper">
#      <span class="shareBox-separator" data-button="" data-id="toggleBox" data-static="" data-value="share-list-1601752400" onclick="">
#       <span class="active">
#        <span class="icon-plus">
#         +
#        </span>
#       </span>
#       <span class="passive">
#        <span class="icon-plus">
#         +
#        </span>
#       </span>
#      </span>
#      <a class="share-button" href="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/">
#       <span class="icon share-empty">
#       </span>
#      </a>
#      <div class="share-list" data-button-target="share-list-1601752400">
#       <ul>
#        <li class="facebook">
#         <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="600" data-id="share" data-name="network_id" data-share-network="Facebook" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="1" data-width="600" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F" target="_blank">
#          <span class="social-bg icon facebook">
#          </span>
#          <span class="name">
#           Share on Facebook
#          </span>
#         </a>
#        </li>
#        <li class="twitter">
#         <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="450" data-id="share" data-name="network_id" data-share-network="Twitter" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="2" data-width="600" href="https://twitter.com/intent/tweet?url=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F&amp;text=FINAL+UPDATE%3A+Quarterly+Plug-In+EV+Sales+Scorecard&amp;via=insideevs.com" target="_blank">
#          <span class="social-bg icon twitter">
#          </span>
#          <span class="name">
#           Share on Twitter
#          </span>
#         </a>
#        </li>
#        <li class="linkedin">
#         <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="600" data-id="share" data-name="network_id" data-share-network="LinkedIn" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="3" data-width="600" href="https://www.linkedin.com/cws/share?url=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F" target="_blank">
#          <span class="social-bg icon linkedin">
#          </span>
#          <span class="name">
#           Share on LinkedIn
#          </span>
#         </a>
#        </li>
#        <li class="flipboard">
#         <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="600" data-id="share" data-name="network_id" data-share-network="Flipboard" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="7" data-width="600" href="https://share.flipboard.com/bookmarklet/popout?url=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F&amp;title=FINAL+UPDATE%3A+Quarterly+Plug-In+EV+Sales+Scorecard&amp;v=2" target="_blank">
#          <span class="social-bg icon flipboard">
#          </span>
#          <span class="name">
#           Share on Flipboard
#          </span>
#         </a>
#        </li>
#        <li class="reddit">
#         <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="600" data-id="share" data-name="network_id" data-share-network="Reddit" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="6" data-width="900" href="https://www.reddit.com/submit?url=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F" target="_blank">
#          <span class="social-bg icon reddit">
#          </span>
#          <span class="name">
#           Share on Reddit
#          </span>
#         </a>
#        </li>
#        <li class="whatsapp">
#         <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="600" data-id="share" data-name="network_id" data-share-network="WhatsApp" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-url="/connect/share/" data-value="6" data-width="600" href="https://api.whatsapp.com/send?text=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F" target="_blank">
#          <span class="social-bg icon whatsapp">
#          </span>
#          <span class="name">
#           Share on WhatsApp
#          </span>
#         </a>
#        </li>
#        <li class="mailto">
#         <a data-button="" data-extra-params="id:'343998',type_id:'1'" data-height="400" data-id="mailTo" data-share-url="https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/" data-width="600" href="mailto:?body=https%3A%2F%2Finsideevs.com%2Fnews%2F343998%2Fmonthly-plug-in-ev-sales-scorecard%2F&amp;subject=FINAL%20UPDATE%3A%20Quarterly%20Plug-In%20EV%20Sales%20Scorecard" target="_blank">
#          <span class="social-bg icon mailto">
#          </span>
#          <span class="name">
#           Send to email
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--<div class="adminInfoBoxx"></div>-->
#   <div class="m1-footer-messages">
#   </div>
#   <script>
#    window.gadsId = false;
#   </script>
#   <script>
#    var m1FooterMessages = [];
#     m1FooterMessages.push({
#         message: "This website uses cookies to ensure you get the best experience on our website. By closing this banner, scrolling this page you consent to the use of cookies. <a id='cookie_accept_link' data-id='footerMessageAccept' data-button='' href='/info/cookie-policy/'>More info.</a>",
#         name: "cookie_accept"
#     });
#   </script>
#   <script defer="" src="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/build/jslangs/insideevs_en_US_1c7a4d6c40d672f35017b11d02f66377.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/dist/js/0_f3778dfc1e009f9995eb.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/dist/js/2_f3778dfc1e009f9995eb.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://cdn.motor1.com/kp/static4ui/prod_v2_eks_165/design/dist/js/11_f3778dfc1e009f9995eb.js" type="text/javascript">
#   </script>
#   <script>
#    gtmDataLayer = [{
#     'currentEdition': 'ev_us',
#     'currentEnv': 'production',
#         'pageType': 'detail',
#             'entityType': 'article',
#             'make': 'BMW',
#                 'pageId': 'index_articles_detail',
#             'entityAuthors': ["Steven Loveday"],
#             'pageUrl': 'https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/',
#             'pageUrlCanonical': 'https://insideevs.com/news/343998/monthly-plug-in-ev-sales-scorecard/',
#             'pageLanguage': 'en',
#             'entityCategories': ["Sales"],
#             'articleType': 'news',
#                     'entityTitle': 'FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard',
#             'pageTitle': 'FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard',
#             'articleId': '343998',
#                     'sessionId': 'df2cb119f362ee6c6d20687d9eb0ffcc'
# }];
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','gtmDataLayer','GTM-TJCLXGW');
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','gtmDataLayer', 'GTM-M4M4LBT');
#   </script>
#   <!-- <script>
#     window.onload = function() {
#
#         if ((typeof $.cookie('PHPSESSID') === 'undefined') || (typeof $.cookie('is_logged_in') !== 'undefined')){
#             $.get('/layout-auth-data/', function(data) {
#                 $('.m1-user-side-label').html(data);
#
#                 var loginButton = document.getElementsByClassName('login')[0];
#                 var registerButton = document.getElementsByClassName('register')[0];
#
#                 if (msnt) {
#                     if (loginButton) {
#                         loginButton.addEventListener('click', function(event){
#                             event.preventDefault();
#                             event.stopPropagation();
#                             window.msnt.register = false;
#                             msnt.openIframeWindow();
#                         });
#                     }
#                     if (registerButton) {
#                         registerButton.addEventListener('click', function(event){
#                         event.preventDefault();
#                         event.stopPropagation();
#                         window.msnt.register = true;
#                         msnt.openIframeWindow();
#                         });
#                     }
#                 }
#             });
#
#             var loginButton = document.getElementsByClassName('login')[0];
#             var registerButton = document.getElementsByClassName('register')[0];
#
#             if (msnt) {
#                 if (loginButton) {
#                     loginButton.addEventListener('click', function(event){
#                         event.preventDefault();
#                         event.stopPropagation();
#                         window.msnt.register = false;
#                         msnt.openIframeWindow();
#                     });
#                 }
#
#                 if (registerButton) {
#                     registerButton.addEventListener('click', function(event){
#                         event.preventDefault();
#                         event.stopPropagation();
#                         window.msnt.register = true;
#                         msnt.openIframeWindow();
#                     });
#                 }
#             }
#         }
#     }
#
# </script> -->
#  </body>
# </html>

# %%
soup.title.text
# Out:
# 'FINAL UPDATE: Quarterly Plug-In EV Sales Scorecard'

# %%
soup.find_all("tr")
# Out:
# [<tr>
#  <td>Category</td>
#  <td><div class="list">
#  <a href="/news/category/sales/">Sales</a>
#  </div></td>
#  </tr>,
#  <tr>
#  <td>Make</td>
#  <td>
#  <div class="list">
#  <a href="/bmw/">BMW</a>
#  <a href="/cadillac/">Cadillac</a>
#  <a href="/audi/">Audi</a>
#  <a href="/chevrolet/">Chevrolet</a>
#  <a href="/chrysler/">Chrysler</a>
#  <a href="/fiat/">Fiat</a>
#  <a href="/ford/">Ford</a>
#  <a href="/honda/">Honda</a>
#  <a href="/hyundai/">Hyundai</a>
#  <a href="/jaguar/">Jaguar</a>
#  <a href="/kia/">Kia</a>
#  <a href="/mercedes-benz/">Mercedes-Benz</a>
#  <a href="/mini/">Mini</a>
#  <a href="/mitsubishi/">Mitsubishi</a>
#  <a href="/nissan/">Nissan</a>
#  <a href="/porsche/">Porsche</a>
#  <a href="/smart/">Smart</a>
#  <a href="/subaru/">Subaru</a>
#  <a href="/toyota/">Toyota</a>
#  <a href="/volkswagen/">Volkswagen</a>
#  <a href="/volvo/">Volvo</a>
#  <a href="/general-motors/">General Motors</a>
#  <a href="/tesla/">Tesla</a>
#  <a href="/daimler/">Daimler</a>
#  </div>
#  </td>
#  </tr>]
